# %% [markdown]
# # Story Telling
#
# ## File Name : "1938_airplane_crashes.csv"

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
airplane_crashes = pd.read_csv("1938_airplane_crashes.csv",header=1)
airplane_crashes
# Out:
#        Months                             Location  Aboard  Fatalities
# 0     January                   Frankfurt, Germany       6           6
# 1    February  Off San Clemente Island, California      14          11
# 2       March             Near Wawona, Cailifornia       9           9
# 3       April                   Near Formia, Italy      19          19
# 4         May                     Balbuena, Mexico       6           1
# 5        June                           Tanganyika       3           3
# 6        July                    Billings, Montana      10          10
# 7      August                    Shishijima, Japan       6           6
# 8   September                           *No Crash*       0           0
# 9     October                 Off Bathurst, Gambia       4           4
# 10   November                    Somerset, England       2           2
# 11   December                           *No Crash*       0           0

# %%
plt.subplots(2,1)
# Out:
# (<Figure size 640x480 with 2 Axes>,
#  array([<AxesSubplot:>, <AxesSubplot:>], dtype=object))

# %%
plt.subplots(1,2,figsize=(14,4))
# Out:
# (<Figure size 1400x400 with 2 Axes>,
#  array([<AxesSubplot:>, <AxesSubplot:>], dtype=object))

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(14,4))

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(14,4))
ax1.bar(airplane_crashes["Months"][0:6],airplane_crashes["Aboard"][0:6])
ax1.bar(airplane_crashes["Months"][0:6],airplane_crashes["Fatalities"][0:6])
ax2.bar(airplane_crashes["Months"][6:12],airplane_crashes["Aboard"][6:12])
ax2.bar(airplane_crashes["Months"][6:12],airplane_crashes["Fatalities"][6:12])
# Out:
# <BarContainer object of 6 artists>

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(14,4))
ax1.bar(airplane_crashes["Months"][0:6],airplane_crashes["Aboard"][0:6])
ax1.bar(airplane_crashes["Months"][0:6],airplane_crashes["Fatalities"][0:6])
ax2.bar(airplane_crashes["Months"][6:12],airplane_crashes["Aboard"][6:12])
ax2.bar(airplane_crashes["Months"][6:12],airplane_crashes["Fatalities"][6:12])
axes=[ax1,ax2]
for i in axes:
        i.xaxis.set_ticks_position('none')
        i.yaxis.set_ticks_position('none')
    pos = ['right','left','bottom','top']
    for j in pos:
        i.spines[j].set_visible(False)
# Out:
#   File "<tokenize>", line 10
#     pos = ['right','left','bottom','top']
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
fig,(ax1,ax2,ax3,ax4) = plt.subplots(4,1,figsize=(8,10))
axes=[ax1,ax2,ax3,ax4]
for i in axes:
    i.plot(airplane_crashes["Months"],airplane_crashes["Aboard"],color="#36013F",alpha=0.5)
    i.plot(airplane_crashes["Months"],airplane_crashes["Fatalities"],color="#2F0909",alpha=0.8)
    i.set_yticklabels([])
    i.set_xticklabels([])
    i.set_xticks([])
    i.set_yticks([])
# Removing Spines
    spines = ["left","right","top","bottom"]
    for  j  in spines:
        i.spines[j].set_visible(False)

# %%
fig,(ax1,ax2,ax3,ax4) = plt.subplots(4,1,figsize=(8,10))
axes=[ax1,ax2,ax3,ax4]
for i in axes:
    i.plot(airplane_crashes["Months"],airplane_crashes["Aboard"],color="#355E3B",alpha=0.5)
    i.plot(airplane_crashes["Months"],airplane_crashes["Fatalities"],color="#3D3635",alpha=1)
    i.set_yticklabels([])
    i.set_xticklabels([])
    i.set_xticks([])
    i.set_yticks([])
# Removing Spines
    spines = ["left","right","top","bottom"]
    for  j  in spines:
        i.spines[j].set_visible(False)

ax1.plot(airplane_crashes["Months"][0:3],airplane_crashes["Aboard"][0:3],color="#004225",linewidth=2.5)
ax2.plot(airplane_crashes["Months"][2:6],airplane_crashes["Aboard"][2:6],color="#004225",linewidth=2.5)
ax3.plot(airplane_crashes["Months"][5:9],airplane_crashes["Aboard"][5:9],color="#004225",linewidth=2.5)
ax4.plot(airplane_crashes["Months"][8:12],airplane_crashes["Aboard"][8:12],color="#004225",linewidth=2.5)


ax1.plot(airplane_crashes["Months"][0:3],airplane_crashes["Fatalities"][0:3],color="#483C32",linewidth=2.5)
ax2.plot(airplane_crashes["Months"][2:6],airplane_crashes["Fatalities"][2:6],color="#483C32",linewidth=2.5)
ax3.plot(airplane_crashes["Months"][5:9],airplane_crashes["Fatalities"][5:9],color="#483C32",linewidth=2.5)
ax4.plot(airplane_crashes["Months"][8:12],airplane_crashes["Fatalities"][8:12],color="#483C32",linewidth=2.5)

# %%
fig,(ax1,ax2,ax3,ax4) = plt.subplots(4,1,figsize=(8,10))
axes=[ax1,ax2,ax3,ax4]
for i in axes:
    i.plot(airplane_crashes["Months"],airplane_crashes["Aboard"],color="#355E3B",alpha=0.5)
    i.plot(airplane_crashes["Months"],airplane_crashes["Fatalities"],color="#3D3635",alpha=1)
    i.set_yticklabels([])
    i.set_xticklabels([])
    i.set_xticks([])
    i.set_yticks([])
# Removing Spines
    spines = ["left","right","top","bottom"]
    for  j  in spines:
        i.spines[j].set_visible(False)

ax1.plot(airplane_crashes["Months"][0:3],airplane_crashes["Aboard"][0:3],color="#004225",linewidth=2.5)
ax2.plot(airplane_crashes["Months"][2:6],airplane_crashes["Aboard"][2:6],color="#004225",linewidth=2.5)
ax3.plot(airplane_crashes["Months"][5:9],airplane_crashes["Aboard"][5:9],color="#004225",linewidth=2.5)
ax4.plot(airplane_crashes["Months"][8:12],airplane_crashes["Aboard"][8:12],color="#004225",linewidth=2.5)


ax1.plot(airplane_crashes["Months"][0:3],airplane_crashes["Fatalities"][0:3],color="#483C32",linewidth=2.5)
ax2.plot(airplane_crashes["Months"][2:6],airplane_crashes["Fatalities"][2:6],color="#483C32",linewidth=2.5)
ax3.plot(airplane_crashes["Months"][5:9],airplane_crashes["Fatalities"][5:9],color="#483C32",linewidth=2.5)
ax4.plot(airplane_crashes["Months"][8:12],airplane_crashes["Fatalities"][8:12],color="#483C32",linewidth=2.5)

#plotting the months
ax1.text(0.5,6.4,"Jan-March",rotation=6)
ax2.text(2.8,5,"April-June",rotation=-72)
ax3.text(5.7,3,"July-Sep",rotation=0)
ax4.text(8.8,0,"Oct-Dec",rotation=0)


ax1.text(0.5,6.4,"",rotation=6)
# Out:
# Text(8.8, 0, 'Oct-Dec')

# %%
airplane_crashes
# Out:
#        Months                             Location  Aboard  Fatalities
# 0     January                   Frankfurt, Germany       6           6
# 1    February  Off San Clemente Island, California      14          11
# 2       March             Near Wawona, Cailifornia       9           9
# 3       April                   Near Formia, Italy      19          19
# 4         May                     Balbuena, Mexico       6           1
# 5        June                           Tanganyika       3           3
# 6        July                    Billings, Montana      10          10
# 7      August                    Shishijima, Japan       6           6
# 8   September                           *No Crash*       0           0
# 9     October                 Off Bathurst, Gambia       4           4
# 10   November                    Somerset, England       2           2
# 11   December                           *No Crash*       0           0

# %%
jan_march = airplane_crashes[0:3]
april_june = airplane_crashes[3:6]
july_sep = airplane_crashes[6:9]
oct_dec = airplane_crashes[9:12]

# %%
jan_march[["Aboard","Fatalities"]].sum()
# Out:
# Aboard        29
# Fatalities    26
# dtype: int64

# %%
april_june[["Aboard","Fatalities"]].sum()
# Out:
# Aboard        28
# Fatalities    23
# dtype: int64

# %%
july_sep[["Aboard","Fatalities"]].sum()
# Out:
# Aboard        16
# Fatalities    16
# dtype: int64

# %%
oct_dec[["Aboard","Fatalities"]].sum()
# Out:
# Aboard        6
# Fatalities    6
# dtype: int64

# %%
fig,(ax1,ax2,ax3,ax4) = plt.subplots(4,1,figsize=(8,10))
axes=[ax1,ax2,ax3,ax4]
for i in axes:
    i.plot(airplane_crashes["Months"],airplane_crashes["Aboard"],color="#355E3B",alpha=0.5)
    i.plot(airplane_crashes["Months"],airplane_crashes["Fatalities"],color="#3D3635",alpha=1)
    i.set_yticklabels([])
    i.set_xticklabels([])
    i.set_xticks([])
    i.set_yticks([])
# Removing Spines
    spines = ["left","right","top","bottom"]
    for  j  in spines:
        i.spines[j].set_visible(False)

ax1.plot(airplane_crashes["Months"][0:3],airplane_crashes["Aboard"][0:3],color="#004225",linewidth=2.5)
ax2.plot(airplane_crashes["Months"][2:6],airplane_crashes["Aboard"][2:6],color="#004225",linewidth=2.5)
ax3.plot(airplane_crashes["Months"][5:9],airplane_crashes["Aboard"][5:9],color="#004225",linewidth=2.5)
ax4.plot(airplane_crashes["Months"][8:12],airplane_crashes["Aboard"][8:12],color="#004225",linewidth=2.5)


ax1.plot(airplane_crashes["Months"][0:3],airplane_crashes["Fatalities"][0:3],color="#483C32",linewidth=2.5)
ax2.plot(airplane_crashes["Months"][2:6],airplane_crashes["Fatalities"][2:6],color="#483C32",linewidth=2.5)
ax3.plot(airplane_crashes["Months"][5:9],airplane_crashes["Fatalities"][5:9],color="#483C32",linewidth=2.5)
ax4.plot(airplane_crashes["Months"][8:12],airplane_crashes["Fatalities"][8:12],color="#483C32",linewidth=2.5)

#plotting the months
ax1.text(0.5,6.4,"Jan-March",rotation=6)
ax2.text(2.8,5,"April-June",rotation=-72)
ax3.text(5.7,3,"July-Sep",rotation=0)
ax4.text(8.8,0,"Oct-Dec",rotation=0)


ax1.text(-0.2,7.5,6,rotation=6,color="#004225")
ax1.text(-0.1,4.2,"6",rotation=6,color="#483C32")
ax1.text(1.8,11,"9",rotation=6,color="#004225")
ax1.text(2,7.5,"9",rotation=6,color="#483C32")


ax2.text(1.8,11,"9",rotation=6,color="#004225")
ax2.text(2,7.5,"9",rotation=6,color="#483C32")
ax2.text(4.8,4.2,"3",rotation=6,color="#004225")
ax2.text(5,1.1,"3",rotation=6,color="#483C32")

ax3.text(4.8,4.2,"3",rotation=6,color="#004225")
ax3.text(5,1.1,"3",rotation=6,color="#483C32")
ax3.text(7.9,1,"0",rotation=6,color="#004225")
ax3.text(8,-2,"0",rotation=6,color="#483C32")

ax4.text(11,1,"0",rotation=6,color="#004225")
ax4.text(11,-3,"0",rotation=6,color="#483C32")
# Out:
# Text(11, -3, '0')

# %%
airplane_crashes["Cumulative Aboard"]= airplane_crashes["Aboard"].cumsum()

# %%
airplane_crashes["Cumulative Fatalities"]= airplane_crashes["Fatalities"].cumsumb

# %%
airplane_crashes
# Out:
#        Months                             Location  Aboard  Fatalities  \
# 0     January                   Frankfurt, Germany       6           6
# 1    February  Off San Clemente Island, California      14          11
# 2       March             Near Wawona, Cailifornia       9           9
# 3       April                   Near Formia, Italy      19          19
# 4         May                     Balbuena, Mexico       6           1
# 5        June                           Tanganyika       3           3
# 6        July                    Billings, Montana      10          10
# 7      August                    Shishijima, Japan       6           6
# 8   September                           *No Crash*       0           0
# 9     October                 Off Bathurst, Gambia       4           4
# 10   November                    Somerset, England       2           2
# 11   December                           *No Crash*       0           0
#
# ...

# %%
c_a = list(airplane_crashes.iloc[[2,5,8,11]]["Cumulative Aboard"])
c_a
# Out:
# [29, 57, 73, 79]

# %%
c_f = list(airplane_crashes.iloc[[2,5,8,11]]["Cumulative Fatalities"])
c_f
# Out:
# [26, 49, 65, 71]

# %%
fig,(ax1,ax2,ax3,ax4) = plt.subplots(4,1,figsize=(8,10))
axes=[ax1,ax2,ax3,ax4]
for i in axes:
    i.plot(airplane_crashes["Months"],airplane_crashes["Aboard"],color="#355E3B",alpha=0.5)
    i.plot(airplane_crashes["Months"],airplane_crashes["Fatalities"],color="#3D3635",alpha=1)
    i.set_yticklabels([])
    i.set_xticklabels([])
    i.set_xticks([])
    i.set_yticks([])
# Removing Spines
    spines = ["left","right","top","bottom"]
    for  j  in spines:
        i.spines[j].set_visible(False)

ax1.plot(airplane_crashes["Months"][0:3],airplane_crashes["Aboard"][0:3],color="#004225",linewidth=2.5)
ax2.plot(airplane_crashes["Months"][2:6],airplane_crashes["Aboard"][2:6],color="#004225",linewidth=2.5)
ax3.plot(airplane_crashes["Months"][5:9],airplane_crashes["Aboard"][5:9],color="#004225",linewidth=2.5)
ax4.plot(airplane_crashes["Months"][8:12],airplane_crashes["Aboard"][8:12],color="#004225",linewidth=2.5)


ax1.plot(airplane_crashes["Months"][0:3],airplane_crashes["Fatalities"][0:3],color="#483C32",linewidth=2.5)
ax2.plot(airplane_crashes["Months"][2:6],airplane_crashes["Fatalities"][2:6],color="#483C32",linewidth=2.5)
ax3.plot(airplane_crashes["Months"][5:9],airplane_crashes["Fatalities"][5:9],color="#483C32",linewidth=2.5)
ax4.plot(airplane_crashes["Months"][8:12],airplane_crashes["Fatalities"][8:12],color="#483C32",linewidth=2.5)

#plotting the months
ax1.text(0.5,6.4,"Jan-March",rotation=6)
ax2.text(2.8,5,"April-June",rotation=-72)
ax3.text(5.7,3,"July-Sep",rotation=0)
ax4.text(8.8,0,"Oct-Dec",rotation=0)


ax1.text(-0.2,7.5,6,rotation=6,color="#004225")
ax1.text(-0.1,4.2,"6",rotation=6,color="#483C32")
ax1.text(1.8,11,"9",rotation=6,color="#004225")
ax1.text(2,7.5,"9",rotation=6,color="#483C32")


ax2.text(1.8,11,"9",rotation=6,color="#004225")
ax2.text(2,7.5,"9",rotation=6,color="#483C32")
ax2.text(4.8,4.2,"3",rotation=6,color="#004225")
ax2.text(5,1.1,"3",rotation=6,color="#483C32")

ax3.text(4.8,4.2,"3",rotation=6,color="#004225")
ax3.text(5,1.1,"3",rotation=6,color="#483C32")
ax3.text(7.9,1,"0",rotation=6,color="#004225")
ax3.text(8,-2,"0",rotation=6,color="#483C32")

ax4.text(11,1,"0",rotation=6,color="#004225")
ax4.text(11,-3,"0",rotation=6,color="#483C32")

c=0
for k in axes:
    k.text(0,22,"Cumulative Aboard :"+str(c_a[c]),weight="bold",color="brown")
    k.text(3.5,22,"Cumulative Fatalities :"+str(c_f[c]),weight="bold",color="brown")
    c+=1
    
#Catchy Heading
ax1.text(3,30,"'Airplane Casualties Analysis'",weight="bold",size = 15)
ax1.text(4,27,"(Airplane Crashes by Month)",size = 12)
# Out:
# Text(4, 27, '(Airplane Crashes by Month)')
